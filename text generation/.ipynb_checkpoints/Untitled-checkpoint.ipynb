# %%
from __future__ import print_function
from keras.layers import Dense, SimpleRNN, Activation
from keras.models import Sequential
import matplotlib.pyplot as plt
import numpy as np

# %%
fin = open('Carroll Lewis. Alices adventures in Wonderland - BooksCafe.Net.txt', 'rb')
lines = []
for line in fin:
    line = line.strip().lower()
    line = line.decode('ascii', 'ignore')
    if len(line) == 0:
        continue
    lines.append(line)
fin.close()
text = ' '.join(lines)

# %%
chars = set([c for c in text])
nb_chars = len(chars)
char2index = dict((c, i) for i, c in enumerate(chars))
index2char = dict((i, c) for i, c in enumerate(chars))

# %%
SEQLEN = 10
STEP = 1

input_chars = []
label_chars = []
for i in range(0, len(text) - SEQLEN, STEP):
    input_chars.append(text[i:i + SEQLEN])
    label_chars.append(text[i + SEQLEN])

# %%
X = np.zeros((len(input_chars), SEQLEN, nb_chars), dtype=np.bool_)
y = np.zeros((len(input_chars), nb_chars), dtype=np.bool_)
for i, input_char in enumerate(input_chars):
    for j, ch in enumerate(input_char):
        X[i, j, char2index[ch]] = 1
    y[i, char2index[label_chars[i]]] = 1

# %%
HIDDEN_SIZE = 128
BATCH_SIZE = 128
NUM_ITERATIONS = 25
NUM_EPOCHS_PER_ITERATION = 1
NUM_PREDS_PER_EPOCH = 100

# %%
model = Sequential()
model.add(SimpleRNN(HIDDEN_SIZE, return_sequences = False, input_shape=(SEQLEN, nb_chars), unroll=True))
model.add(Dense(nb_chars))
model.add(Activation('softmax'))
model.compile(loss='categorical_crossentropy', optimizer='rmsprop')

# %%
for iteration in range(NUM_ITERATIONS):
    print('=' * 50)
    print('Iteration #: %d' % (iteration))
    model.fit(X, y, batch_size=BATCH_SIZE, epochs=NUM_EPOCHS_PER_ITERATION)
    
    test_idx = np.random.randint(len(input_chars))
    test_chars = input_chars[test_idx]
    print('Generating from seed: %s' % (test_chars))
    print(test_chars, end='')
    for i in range(NUM_PREDS_PER_EPOCH):
        Xtest = np.zeros((1, SEQLEN, nb_chars))
        for i, ch in enumerate(test_chars):
            Xtest[0, i, char2index[ch]] = 1
        pred = model.predict(Xtest, verbose=0)[0]
        ypred = index2char[np.argmax(pred)]
        print(ypred, end='')
        # сдвинуться вперед на test_chars + ypred
        test_chars = test_chars[1:] + ypred
    print()
# Out:
# ==================================================
# Iteration #: 0
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.5745
# Generating from seed: l must hav
# l must have the soon the sald the sald the sald the sald the sald the sald the sald the sald the sald the sald
# ==================================================
# Iteration #: 1
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.0621
# Generating from seed: ll make yo
# ll make you don the mad the was see to the was see to the was see to the was see to the was see to the was see
# ==================================================
# Iteration #: 2
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.9480
# Generating from seed: own busine
# own busine the said the dong the said the dong the said the dong the said the dong the said the dong the said
# ==================================================
# Iteration #: 3
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.8681
# Generating from seed:  toast,) s
#  toast,) she had the cane the came of the came of the came of the came of the came of the came of the came of
# ==================================================
# Iteration #: 4
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7977
# Generating from seed: r one, the
# r one, the rabbet rearing the right in the right in the right in the right in the right in the right in the ri
# ==================================================
# Iteration #: 5
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.7437
# Generating from seed: ing,' the
# ing,' the king to herself an the catere to the goon wish a said to herself an the catere to the goon wish a sa
# ==================================================
# Iteration #: 6
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6845
# Generating from seed: a whiting
# a whiting to her alice said the gryphon a pight the catterse the cat and white rabbit her all who the rabbit h
# ==================================================
# Iteration #: 7
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6500
# Generating from seed: vely garde
# vely garden to the caterping the caterping the caterping the caterping the caterping the caterping the caterpi
# ==================================================
# Iteration #: 8
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.6165
# Generating from seed: cup,' inte
# cup,' inte dreat her had not the cat the rabbit her had not the cat the rabbit her had not the cat the rabbit
# ==================================================
# Iteration #: 9
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5694
# Generating from seed:  'soles an
#  'soles and she was not the mouse so she sook the mock turtle so she was not the mouse so she sook the mock tu
# ==================================================
# Iteration #: 10
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5497
# Generating from seed: with anoth
# with another she was the come up and she was por it was the say the come up and she was por it was the say the
# ==================================================
# Iteration #: 11
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5246
# Generating from seed: old you bu
# old you but it was so the was a little the was a little the was a little the was a little the was a little the
# ==================================================
# Iteration #: 12
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.5059
# Generating from seed: f i'd only
# f i'd only the this the took up and she this said to her all the dormouse was a little shouse of the took up a
# ==================================================
# Iteration #: 13
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4863
# Generating from seed: e's more e
# e's more entered and then she was not and alice was goonite the panch and all the rabbit her hand and she was
# ==================================================
# Iteration #: 14
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4657
# Generating from seed:  majesty,'
#  majesty,' said the dormouse said to herself, 'you are was a great car a low man the looked at the say to the
# ==================================================
# Iteration #: 15
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4596
# Generating from seed: lt that th
# lt that the gryphon and all the this the this the this the this the this the this the this the this the this t
# ==================================================
# Iteration #: 16
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4392
# Generating from seed: hat are th
# hat are the same of the same of the same of the same of the same of the same of the same of the same of the sa
# ==================================================
# Iteration #: 17
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4358
# Generating from seed: ll she was
# ll she was not any of the look down and she could not a more that it was some of the look down and she could n
# ==================================================
# Iteration #: 18
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4184
# Generating from seed: be what he
# be what her foot and she could not any she had the more the court of the court of the court of the court of th
# ==================================================
# Iteration #: 19
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.4076
# Generating from seed: ent and mo
# ent and more the tore say it was a little alice could be one of the tread it made one of the tread it made one
# ==================================================
# Iteration #: 20
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3982
# Generating from seed: , if you w
# , if you was spee they was got it was some of the say the rabbit with the dormouse, and the dormouse, and the
# ==================================================
# Iteration #: 21
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3863
# Generating from seed:  pretend t
#  pretend to be and the rabbit words had not a minute or to stought the shore sound her for a minute or to stou
# ==================================================
# Iteration #: 22
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3808
# Generating from seed: re inside,
# re inside, and she went on the dormouse she well as she could not it was some of the dormouse she well as she
# ==================================================
# Iteration #: 23
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3685
# Generating from seed: nd get rea
# nd get reading to the caterpillar to the poor a ding to the caterpillar to the poor a ding to the caterpillar
# ==================================================
# Iteration #: 24
# 1108/1108 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 1.3577
# Generating from seed: something
# something a was the court. 'what it was soor of the said to herself to say it was not and she could not an all
